# %% [markdown]
# # carregando dataset

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %% [markdown]
# #Caracteristicas da Base

# %%
dados = pd.read_csv(url, sep=';')
corpo_dados = dados.shape
linhas, colunas = corpo_dados
print(f'O data frame possui {linhas} linhas  e {colunas} colunas')
colunas = dados.columns
colunas
dados.info() # p/ verificar o tipo de dado de cada coluna
# Out:
# O data frame possui 32960 linhas  e 9 colunas
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos', 'Valor']] # int sao dados inteiros e float dados decimais
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# #Analise Exploratoria

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor'].mean()
# Out:
# np.float64(12952.659715265761)

# %%
dados.groupby('Tipo').mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# Indústria                     0.000000   0.000000   0.000000     22.000000
# Loft                          1.117647   0.666667   0.372549     58.372549
# Loja Shopping/ Ct Comercial   0.044534   6.874494   0.008097     88.109312
# Loja/Salão                    0.010519   1.217391   0.043478    228.852034
# Loteamento/Condomínio         0.000000   0.000000   0.000000   2069.000000
# Pousada/Chalé                23.000000   0.000000  23.000000    862.000000
# Prédio Inteiro                0.335548  11.199336   0.019934   1773.837209
# Quitinete                     0.834928   0.017943   0.037081     28.954545
# Studio                        0.500000   0.250000   0.000000    103.250000
# Sítio                         5.100000   1.000000   3.800000  15217.000000
# Terreno Padrão                0.042857   0.057143   0.000000   5044.814286
#
#                                      Valor    Condominio           IPTU
# Tipo
# Apartamento                    4744.614648   1722.653697     686.170413
# Box/Garagem                    1899.756098    305.450000     125.846154
# Casa                           6793.454922    931.280952    1582.506394
# Casa Comercial                14478.264151   1935.709677    1707.386740
# Casa de Condomínio            11952.061245   1342.025527    3252.517730
# Casa de Vila                   1574.369478    138.768421     183.878788
# Chácara                        4900.000000           NaN            NaN
# Conjunto Comercial/Sala       14715.045521   4512.218100    1399.596571
# Flat                           4546.189076   2027.720554     493.166667
# Galpão/Depósito/Armazém       53407.062600  10560.308824    5050.465241
# Hotel                         25000.000000           NaN    6202.000000
# Indústria                    120000.000000           NaN            NaN
# Loft                           2557.882353    869.239130     238.243243
# Loja Shopping/ Ct Comercial    8126.178862   1790.109005    1052.415459
# Loja/Salão                    13769.646770   2605.601954    2670.331409
# Loteamento/Condomínio         22000.000000           NaN    4885.000000
# Pousada/Chalé                  1480.000000    295.000000            NaN
# Prédio Inteiro               498637.239203  55066.750000  165480.022472
# Quitinete                      1246.840909    427.341969      75.790741
# Studio                         2400.000000    549.000000     151.250000
# Sítio                         12499.000000           NaN    5848.800000
# Terreno Padrão                32567.714286      1.000000    5138.170732

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor').round(2)
# Out:
#                                  Valor
# Tipo
# Quitinete                      1246.84
# Pousada/Chalé                  1480.00
# Casa de Vila                   1574.37
# Box/Garagem                    1899.76
# Studio                         2400.00
# Loft                           2557.88
# Flat                           4546.19
# Apartamento                    4744.61
# Chácara                        4900.00
# Casa                           6793.45
# Loja Shopping/ Ct Comercial    8126.18
# Casa de Condomínio            11952.06
# Sítio                         12499.00
# Loja/Salão                    13769.65
# Casa Comercial                14478.26
# Conjunto Comercial/Sala       14715.05
# Loteamento/Condomínio         22000.00
# Hotel                         25000.00
# Terreno Padrão                32567.71
# Galpão/Depósito/Armazém       53407.06
# Indústria                    120000.00
# Prédio Inteiro               498637.24

# %%
df_Preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor').round(2)
df_Preco_tipo.plot(kind='barh', figsize=(14, 10), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Imoveis Residenciais

# %%
#metodo unique
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
dados.query('@imoveis_comerciais in Tipo') # mostra os imoveis comerciais
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
#          Valor  Condominio    IPTU
# 2       5200.0      4020.0  1111.0
# 9      35000.0     19193.0  3030.0
# 16     28000.0         NaN  3563.0
# 26      1100.0       600.0     NaN
# 29      1300.0       950.0     NaN
# ...        ...         ...     ...
# 32942   2000.0      1096.0     NaN
# 32946   4000.0      1412.0   496.0
# 32948    600.0      1035.0    83.0
# 32954  14000.0         NaN     NaN
# 32959   6500.0      4206.0  1109.0
#
# [9849 rows x 9 columns]

# %%
df = dados.query('@imoveis_comerciais not in Tipo')
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_Preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor').round(2)
df_Preco_tipo.plot(kind='barh', figsize=(14, 10), color = 'purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# # Percentual de cada tipo de Imovel

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df.Tipo.value_counts(normalize=True) # metodo value_counts
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
df.Tipo.value_counts(normalize=True).to_frame# metodo to_frame p/ passar uma serie p/ dataframe
# Out:
# <bound method Series.to_frame of Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64>

# %%
df_percentual_tipo = df.Tipo.value_counts(normalize=True).to_frame()
df_percentual_tipo.plot(kind='bar', figsize=(8, 6), color = 'green',
xlabel='Tipos', ylabel='Percentual'                        )
# Out:
# <Axes: xlabel='Tipos', ylabel='Percentual'>

# %%
df.query('Tipo == "Apartamento"')
dados_apartamento = df.query('Tipo == "Apartamento"')
dados_apartamento.head()
dados_apartamento.Quartos.mean()
df
df.Bairro.value_counts()
dados.groupby('Bairro')[['Valor']].mean().sort_values('Valor').round(2).tail(5)
dados.groupby('Bairro')[['Valor']].mean().sort_values('Valor').round(2).tail(5).plot(kind='barh', figsize=(12, 6), color = 'purple')
# Out:
# <Axes: ylabel='Bairro'>

# %%
# Salvando o DataFrame em uma variável
df_exemplo = df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# Alterando o nome da coluna "Proportion" para "Percentuais"
df_exemplo.rename(columns={'proportion': 'Percentuais'}, inplace=True)

# Visualizando o DataFrame
df_exemplo
# Out:
#                     Percentuais
# Tipo
# Apartamento            0.845139
# Casa                   0.041842
# Casa de Condomínio     0.043096
# Casa de Vila           0.010774
# Flat                   0.020596
# Loft                   0.002207
# Quitinete              0.036173
# Studio                 0.000173

# %% [markdown]
# # Tratando dados nulos

# %%
dados.isnull()# verifica se o dado existente é nulo
dados.isnull().sum() # soma quantos dados sao nulos
# Out:
# Tipo              0
# Bairro            0
# Quartos           0
# Vagas             0
# Suites            0
# Area              0
# Valor            17
# Condominio     4093
# IPTU          10237
# dtype: int64

# %%
dados.fillna(0) # substitui todos os valores nulos por 0
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         0.0     0.0
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     0.0
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     0.0
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
dados = dados.fillna(0) # substitui todos os valores nulos por 0
dados.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# # Remover registros inconsistentes da base

# %%
dados.query('Valor == 0 or IPTU == 0')
dados_incosistentes = dados.query('Valor == 0 or IPTU == 0').index
dados.drop(dados_incosistentes, axis=0, inplace=True)

# %%
dados.query('Valor == 0 or IPTU == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# # metodo filtro

# %%
dados['Quartos'] == 1
# Out:
# 0         True
# 2        False
# 3         True
# 6        False
# 9        False
#          ...
# 32953    False
# 32955    False
# 32956    False
# 32957    False
# 32959    False
# Name: Quartos, Length: 22716, dtype: bool

# %%
selecao1 = dados['Quartos'] == 1
selecao2 = dados['Valor'] < 1200

dados_filtro1 = dados[selecao1 & selecao2] # apartamentos com quartos e exatamente 1 quarto e valor de aluguel menor doq 1200
dados_filtro1
# Out:
#               Tipo       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento       Centro        1      0       0    15   800.0
# 28     Apartamento       Tijuca        1      0       0    48   750.0
# 54     Apartamento       Centro        1      0       0    27   750.0
# 94     Apartamento       Centro        1      1       0    37  1100.0
# 148    Apartamento  Vila Isabel        1      0       0    37  1000.0
# ...            ...          ...      ...    ...     ...   ...     ...
# 32617  Apartamento    Pechincha        1      0       1    69   900.0
# 32627  Apartamento       Glória        1      0       0    46  1100.0
# 32714  Apartamento     Botafogo        1      0       0    21  1000.0
# 32763    Quitinete       Glória        1      0       0    10   400.0
# 32950  Apartamento       Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 28          772.0   25.0
# 54          371.0   19.0
# 94          540.0  900.0
# 148         285.0   24.0
# ...           ...    ...
# 32617       640.0  126.0
# 32627       453.0   32.0
# 32714       282.0   25.0
# 32763       107.0   10.0
# 32950       360.0   25.0
#
# [571 rows x 9 columns]

# %%
selecao = (dados['Quartos'] > 1) & (dados['Valor'] < 3000) & (dados['Area'] > 70)
dados_filtro2 = dados[selecao] # aplica os filtros que fiz em cima
dados[selecao]
df_2 = dados[selecao]

# %% [markdown]
# # Salvando Dados

# %%
dados.to_csv('dados_apartamentos.csv', index=False)

# %%
pd.read_csv('dados_apartamentos.csv')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 2                  Apartamento                Centro        1      0       0
# 3                  Apartamento              Cachambi        2      0       0
# 4      Conjunto Comercial/Sala                Centro        0      3       0
# ...                        ...                   ...      ...    ...     ...
# 22711              Apartamento                 Méier        2      0       0
# 22712                Quitinete                Centro        0      0       0
# 22713              Apartamento           Jacarepaguá        3      1       2
# 22714              Apartamento  São Francisco Xavier        2      1       0
# 22715  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 0        40   1700.0       500.0    60.0
# 1       150   5200.0      4020.0  1111.0
# 2        15    800.0       390.0    20.0
# 3        50   1300.0       301.0    17.0
# 4       695  35000.0     19193.0  3030.0
# ...     ...      ...         ...     ...
# 22711    70    900.0       490.0    48.0
# 22712    27    800.0       350.0    25.0
# 22713    78   1800.0       800.0    40.0
# 22714    48   1400.0       509.0    37.0
# 22715   250   6500.0      4206.0  1109.0
#
# [22716 rows x 9 columns]

# %%
dados.to_csv('dados_apartamentos.csv', index=False, sep=';')

# %%
pd.read_csv('dados_apartamentos.csv', sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 2                  Apartamento                Centro        1      0       0
# 3                  Apartamento              Cachambi        2      0       0
# 4      Conjunto Comercial/Sala                Centro        0      3       0
# ...                        ...                   ...      ...    ...     ...
# 22711              Apartamento                 Méier        2      0       0
# 22712                Quitinete                Centro        0      0       0
# 22713              Apartamento           Jacarepaguá        3      1       2
# 22714              Apartamento  São Francisco Xavier        2      1       0
# 22715  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 0        40   1700.0       500.0    60.0
# 1       150   5200.0      4020.0  1111.0
# 2        15    800.0       390.0    20.0
# 3        50   1300.0       301.0    17.0
# 4       695  35000.0     19193.0  3030.0
# ...     ...      ...         ...     ...
# 22711    70    900.0       490.0    48.0
# 22712    27    800.0       350.0    25.0
# 22713    78   1800.0       800.0    40.0
# 22714    48   1400.0       509.0    37.0
# 22715   250   6500.0      4206.0  1109.0
#
# [22716 rows x 9 columns]

# %% [markdown]
# #Salvando dados_filtro1

# %%
dados_filtro1
# Out:
#               Tipo       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento       Centro        1      0       0    15   800.0
# 28     Apartamento       Tijuca        1      0       0    48   750.0
# 54     Apartamento       Centro        1      0       0    27   750.0
# 94     Apartamento       Centro        1      1       0    37  1100.0
# 148    Apartamento  Vila Isabel        1      0       0    37  1000.0
# ...            ...          ...      ...    ...     ...   ...     ...
# 32617  Apartamento    Pechincha        1      0       1    69   900.0
# 32627  Apartamento       Glória        1      0       0    46  1100.0
# 32714  Apartamento     Botafogo        1      0       0    21  1000.0
# 32763    Quitinete       Glória        1      0       0    10   400.0
# 32950  Apartamento       Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 28          772.0   25.0
# 54          371.0   19.0
# 94          540.0  900.0
# 148         285.0   24.0
# ...           ...    ...
# 32617       640.0  126.0
# 32627       453.0   32.0
# 32714       282.0   25.0
# 32763       107.0   10.0
# 32950       360.0   25.0
#
# [571 rows x 9 columns]

# %%
dados_filtro1.to_csv('dados_filtro1.csv', index=False, sep=';')
pd.read_csv('dados_filtro1.csv', sep=';')
# Out:
#             Tipo       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Apartamento       Centro        1      0       0    15   800.0
# 1    Apartamento       Tijuca        1      0       0    48   750.0
# 2    Apartamento       Centro        1      0       0    27   750.0
# 3    Apartamento       Centro        1      1       0    37  1100.0
# 4    Apartamento  Vila Isabel        1      0       0    37  1000.0
# ..           ...          ...      ...    ...     ...   ...     ...
# 566  Apartamento    Pechincha        1      0       1    69   900.0
# 567  Apartamento       Glória        1      0       0    46  1100.0
# 568  Apartamento     Botafogo        1      0       0    21  1000.0
# 569    Quitinete       Glória        1      0       0    10   400.0
# 570  Apartamento       Tijuca        1      0       0    28  1000.0
#
#      Condominio   IPTU
# 0         390.0   20.0
# 1         772.0   25.0
# 2         371.0   19.0
# 3         540.0  900.0
# 4         285.0   24.0
# ..          ...    ...
# 566       640.0  126.0
# 567       453.0   32.0
# 568       282.0   25.0
# 569       107.0   10.0
# 570       360.0   25.0
#
# [571 rows x 9 columns]

# %% [markdown]
# #dados_filtros 2

# %%
dados_filtro2 = dados[selecao]
dados_filtro2
dados_filtro2.to_csv('dados_filtragem_2.csv', index= False, sep=';')
pd.read_csv('dados_filtragem_2.csv',sep=';')
# Out:
#              Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0     Apartamento       Lins de Vasconcelos        3      1       1    90
# 1     Apartamento                    Tijuca        2      1       0   110
# 2     Apartamento           Barra da Tijuca        3      1       1    72
# 3     Apartamento  Recreio dos Bandeirantes        3      1       2    92
# 4     Apartamento  Recreio dos Bandeirantes        2      1       2    83
# ...           ...                       ...      ...    ...     ...   ...
# 3396  Apartamento  Recreio dos Bandeirantes        2      1       1   105
# 3397  Apartamento               Jacarepaguá        2      1       1    78
# 3398  Apartamento           Barra da Tijuca        2      1       1    85
# 3399  Apartamento           Barra da Tijuca        3      2       0    98
# 3400  Apartamento               Jacarepaguá        3      1       2    78
#
#        Valor  Condominio   IPTU
# 0     1500.0       455.0   14.0
# 1     1900.0       700.0  138.0
# 2     2350.0       600.0   70.0
# 3     2300.0       840.0  200.0
# 4     1600.0      1160.0  157.0
# ...      ...         ...    ...
# 3396  2100.0       648.0  156.0
# 3397  2200.0       790.0  180.0
# 3398  2250.0      1561.0  197.0
# 3399  2300.0       887.0  177.0
# 3400  1800.0       800.0   40.0
#
# [3401 rows x 9 columns]

# %% [markdown]
# # criando colunas numericas

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')
dados['Valor por mes'] = dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor por mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dados['valor_por_ano'] = dados['IPTU'] + dados['Valor por mes'] * 12
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor por mes  valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# #colunas categoricas

# %%
dados['Descricao'] = dados['Tipo'] + ' | ' + dados['Bairro']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor por mes  valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                    Descricao
# 0                     Quitinete | Copacabana
# 1                     Casa | Jardim Botânico
# 2  Conjunto Comercial/Sala | Barra da Tijuca
# 3                       Apartamento | Centro
# 4                 Apartamento | Higienópolis

# %%
dados['Descricao'] = dados['Tipo'] + ' | ' + dados['Bairro'] + ' Com ' \
 + dados['Quartos'].astype(str) + ' Quarto(s)' + \
 ' e ' + dados['Vagas'].astype(str) + ' vaga(s) de garagem'
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor por mes  valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao
# 0  Quitinete | Copacabana Com 1 Quarto(s) e 0 vag...
# 1  Casa | Jardim Botânico Com 2 Quarto(s) e 0 vag...
# 2  Conjunto Comercial/Sala | Barra da Tijuca Com ...
# 3  Apartamento | Centro Com 1 Quarto(s) e 0 vaga(...
# 4  Apartamento | Higienópolis Com 1 Quarto(s) e 0...

# %% [markdown]
# #colunas binarias

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas Suites  Area  \
# 0                Quitinete       Copacabana        1      0    Não    40
# 1                     Casa  Jardim Botânico        2      0   SIM    100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4    Não   150
# 3              Apartamento           Centro        1      0    Não    15
# 4              Apartamento     Higienópolis        1      0    Não    48
#
#     Valor  Condominio    IPTU  Valor por mes  valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao
# 0  Quitinete | Copacabana Com 1 Quarto(s) e 0 vag...
# 1  Casa | Jardim Botânico Com 2 Quarto(s) e 0 vag...
# 2  Conjunto Comercial/Sala | Barra da Tijuca Com ...
# 3  Apartamento | Centro Com 1 Quarto(s) e 0 vaga(...
# 4  Apartamento | Higienópolis Com 1 Quarto(s) e 0...
